# %%
import pandas as pd 

df = pd.read_csv("draw_data/ppl_ptb.csv")
df.head()
# Out:
#    Step  RACs_ptb - perplexity_valid  RACs_ptb - perplexity_valid__MIN  \
# 0     0                   356.927277                        356.927277
# 1     2                   303.095459                        303.095459
# 2     4                   273.269043                        273.269043
# 3     6                   246.071091                        246.071091
# 4     8                   226.521576                        226.521576
#
#    RACs_ptb - perplexity_valid__MAX  RNN_ptb - perplexity_valid  \
# 0                        356.927277                  382.409546
# 1                        303.095459                  316.257111
# 2                        273.269043                  271.691895
# 3                        246.071091                  244.919983
# 4                        226.521576                  227.115601
#
#    RNN_ptb - perplexity_valid__MIN  RNN_ptb - perplexity_valid__MAX  \
# 0                       382.409546                       382.409546
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rc('xtick', labelsize=17) 
matplotlib.rc('ytick', labelsize=17) 
# plt.plot(df['Step'],df['RACs_ptb - perplexity_valid'],label = "TNLM-RACs",linewidth = 2)
# plt.plot(df['Step'],df['RNN_ptb - perplexity_valid'],label = "RNN",linewidth = 2)
# plt.plot(df['Step'],df['MRNN_ptb - perplexity_valid'],label = "TNLM-M",linewidth = 2)
# plt.plot(df['Step'],df['MIRNN_ptb - perplexity_valid'],label = "TNLM-MI",linewidth = 2)
# plt.plot(df['Step'],df['TinyTNLM_ptb - perplexity_valid'],label = "TNLM-Tiny", linewidth = 2)
# plt.plot(df['Step'],df['Second_ptb - perplexity_valid'],label = "TNLM-Second", linewidth = 2)
# plt.xlabel("training step")
# plt.ylabel("Validation PPL")
# # plt.plot(df_result['year'],df_result['statistic'],marker='o',label = "statistic", linestyle=':',linewidth = 2,color = "red")
# plt.legend()
# plt.savefig("image/cell_validation_comparision.png",dpi = 600)

# matplotlib.rcParams['figure.figsize'] = [10, 10] # for square canvas
# matplotlib.rcParams['figure.subplot.left'] = 0
# matplotlib.rcParams['figure.subplot.bottom'] = 1
# matplotlib.rcParams['figure.subplot.right'] = 1
# matplotlib.rcParams['figure.subplot.top'] = 1

# %%
from turtle import color

xlabel_size = 20
ylabel_size = 20
# plt.figure(figsize=(13,10), dpi= 200)
plt.figure(dpi= 200)
matplotlib.rc('xtick', labelsize=17) 
matplotlib.rc('ytick', labelsize=17) 
plt.plot(df['Step'],df['RACs_ptb - perplexity_valid'],label = "RACs",linewidth = 3)
plt.plot(df['Step'],df['MIRNN_ptb - perplexity_valid'],label = "MI-RNNs",linewidth = 3, color = "red")
plt.xlabel("training step",fontsize=xlabel_size)
plt.ylabel("Validation PPL",fontsize=ylabel_size)
plt.rc('legend', fontsize=20)
plt.legend()
plt.savefig("image/rac_mi.png",dpi = 600)

# %% [markdown]
# # Second order Activation and non Activation

# %%
df_s = pd.read_csv("draw_data/non_activation_activation.csv")
df_s.head()
# Out:
#    Step  Second_ptb_activation - perplexity_valid  \
# 0     0                                314.886932
# 1     2                                255.361740
# 2     4                                222.380890
# 3     6                                204.926208
# 4     8                                193.101959
#
#    Second_ptb_activation - perplexity_valid__MIN  \
# 0                                     314.886932
# 1                                     255.361740
# 2                                     222.380890
# 3                                     204.926208
# 4                                     193.101959
#
#    Second_ptb_activation - perplexity_valid__MAX  \
# 0                                     314.886932
# 1                                     255.361740
# 2                                     222.380890
# 3                                     204.926208
# 4                                     193.101959
#
#    Second_ptb_non-activation - perplexity_valid  \
# ...

# %%
plt.figure(dpi= 200)
plt.plot(df_s['Step'],df_s['Second_ptb_non-activation - perplexity_valid'],label = "Second-linear",linewidth = 3 )
plt.plot(df_s['Step'],df_s['Second_ptb_activation - perplexity_valid'],label = "Second-order RNNs",linewidth = 3, color = "red")
plt.xlabel("training step",fontsize=xlabel_size)
plt.ylabel("Validation PPL",fontsize=ylabel_size)
plt.legend()
plt.rc('legend', fontsize=20)
plt.savefig("image/second_linear_tanh.png",dpi = 600)

# %% [markdown]
# <!--draw -->
#
# # draw rank

# %%
df_rank = pd.read_csv("draw_data/rank_ptb_train_ppl.csv")
df_rank.head()
# Out:
#    Step  rank: 25 - perplexity/train  rank: 25 - perplexity/train__MIN  \
# 0     1                   333.754272                        333.754272
# 1     3                   168.157532                        168.157532
# 2     5                   138.844879                        138.844879
# 3     7                   122.904587                        122.904587
# 4     9                   112.699425                        112.699425
#
#    rank: 25 - perplexity/train__MAX  rank: 20 - perplexity/train  \
# 0                        333.754272                   370.129761
# 1                        168.157532                   182.630051
# 2                        138.844879                   152.163681
# 3                        122.904587                   135.293777
# 4                        112.699425                   124.663483
#
#    rank: 20 - perplexity/train__MIN  rank: 20 - perplexity/train__MAX  \
# 0                        370.129761                        370.129761
# ...

# %%
plt.plot(df_s['Step'],df_rank['rank: 35 - perplexity/train'],label = "rank=35",linewidth = 3)
plt.plot(df_s['Step'],df_rank['rank: 30 - perplexity/train'],label = "rank=30",linewidth = 3)
plt.plot(df_s['Step'],df_rank['rank: 25 - perplexity/train'],label = "rank=25",linewidth = 3)
plt.plot(df_s['Step'],df_rank['rank: 20 - perplexity/train'],label = "rank=20",linewidth = 3)
plt.plot(df_s['Step'],df_rank['rank: 10 - perplexity/train'],label = "rank=10",linewidth = 3)
plt.plot(df_s['Step'],df_rank['rank: 5 - perplexity/train'],label = "rank=5",linewidth = 3)
plt.rc('legend', fontsize=15)
plt.legend()

# plt.plot(df_s['Step'],df_s['Second_ptb_activation - perplexity_valid'],label = "Second-tanh",linewidth = 3,color = "red")
plt.xlabel("training step",fontsize=12)
plt.ylabel("Training PPL",fontsize=14)
plt.savefig("image/rank_train_ppl.png",dpi = 600)

# %%
df_rank = pd.read_csv("draw_data/rank_ptb_val_ppl.csv")
df_rank.head()
# Out:
#    Step  rank: 25 - perplexity_valid  rank: 25 - perplexity_valid__MIN  \
# 0     0                   197.646011                        197.646011
# 1     2                   161.808441                        161.808441
# 2     4                   144.692245                        144.692245
# 3     6                   137.219437                        137.219437
# 4     8                   131.461411                        131.461411
#
#    rank: 25 - perplexity_valid__MAX  rank: 20 - perplexity_valid  \
# 0                        197.646011                   215.342041
# 1                        161.808441                   173.182327
# 2                        144.692245                   155.360641
# 3                        137.219437                   147.461685
# 4                        131.461411                   144.329865
#
#    rank: 20 - perplexity_valid__MIN  rank: 20 - perplexity_valid__MAX  \
# 0                        215.342041                        215.342041
# ...

# %%
# plt.plot(df_rank['Step'],df_rank['rank: 35 - perplexity_valid'],label = "rank=35",linewidth = 3)
# plt.plot(df_rank['Step'],df_rank["rank: 30 - perplexity_valid"],label = "rank=30",linewidth = 3)
# plt.plot(df_rank['Step'],df_rank["rank: 25 - perplexity_valid"],label = "rank=25",linewidth = 3)
# plt.plot(df_rank['Step'],df_rank['rank: 20 - perplexity_valid'],label = "rank=20",linewidth = 3)
# plt.plot(df_rank['Step'],df_rank['rank: 10 - perplexity_valid'],label = "rank=10",linewidth = 3)
# plt.plot(df_rank['Step'],df_rank['rank: 5 - perplexity_valid'],label = "rank=5",linewidth = 3)

# plt.legend()
# plt.xlabel("training step",fontsize=12)
# plt.ylabel("Validation Perplexity",fontsize=14)
# plt.savefig("image/rank_val_ppl.png",dpi = 600)

# %%
df_rank = pd.read_csv("draw_data/rank_ptb_val_ppl.csv")
df_rank.head()
# Out:
#    Step  rank: 25 - perplexity_valid  rank: 25 - perplexity_valid__MIN  \
# 0     0                   197.646011                        197.646011
# 1     2                   161.808441                        161.808441
# 2     4                   144.692245                        144.692245
# 3     6                   137.219437                        137.219437
# 4     8                   131.461411                        131.461411
#
#    rank: 25 - perplexity_valid__MAX  rank: 20 - perplexity_valid  \
# 0                        197.646011                   215.342041
# 1                        161.808441                   173.182327
# 2                        144.692245                   155.360641
# 3                        137.219437                   147.461685
# 4                        131.461411                   144.329865
#
#    rank: 20 - perplexity_valid__MIN  rank: 20 - perplexity_valid__MAX  \
# 0                        215.342041                        215.342041
# ...

# %% [markdown]
# # Linear and non-linear

# %%
df_linear_analysis = pd.read_csv("draw_data/ttlm_linear_analysis.csv")
df_linear_analysis.head()
# Out:
#    Step  TinyTNLM_wiki_linear - perplexity_valid  \
# 0     0                               191.203583
# 1     2                               157.853485
# 2     4                               142.295303
# 3     6                               132.158020
# 4     8                               126.170975
#
#    TinyTNLM_wiki_linear - perplexity_valid__MIN  \
# 0                                    191.203583
# 1                                    157.853485
# 2                                    142.295303
# 3                                    132.158020
# 4                                    126.170975
#
#    TinyTNLM_wiki_linear - perplexity_valid__MAX  \
# 0                                    191.203583
# 1                                    157.853485
# 2                                    142.295303
# 3                                    132.158020
# 4                                    126.170975
#
#    TinyTNLM2_wiki_linear - perplexity_valid  \
# ...

# %%
plt.figure(dpi= 200)
plt.plot(df_linear_analysis['Step'],df_linear_analysis['TinyTNLM_wiki_linear - perplexity_valid'],label = "TTLM-Large",linewidth = 3)
plt.plot(df_linear_analysis['Step'],df_linear_analysis['TinyTNLM_wiki_tanh - perplexity_valid'],label = "TTLM-Large-tanh",linewidth = 3,color="red")
plt.xlabel("training step",fontsize=xlabel_size)
plt.ylabel("Validation PPL",fontsize=ylabel_size)
plt.rc('legend', fontsize=20)
plt.legend()

plt.savefig("image/TTLM-Large_activation_comparision.png",dpi = 600)

# %%
plt.figure(dpi= 200)
plt.plot(df_linear_analysis['Step'],df_linear_analysis['TinyTNLM2_wiki_linear - perplexity_valid'],label = "TTLM-Tiny",linewidth = 3)
plt.plot(df_linear_analysis['Step'],df_linear_analysis['TinyTNLM2_wiki_tanh - perplexity_valid'],label = "TTLM-Tiny-tanh",linewidth = 3,color="red")
plt.xlabel("training step",fontsize=xlabel_size)
plt.ylabel("Validation PPL",fontsize=ylabel_size)
plt.rc('legend', fontsize=20)
plt.legend()

plt.savefig("image/TTLM-Tiny_activation_comparision.png",dpi = 600)

# %% [markdown]
# # draw rank to test ppl

# %%
df_rank_ppl = pd.read_csv("draw_data/rank_ptb_testppl.csv")
df_rank_ppl
# Out:
#    Step  cell: TinyTNLM - perplexity_test  \
# 0   100                        110.495809
#
#    cell: TinyTNLM - perplexity_test__MIN  \
# 0                              97.476067
#
#    cell: TinyTNLM - perplexity_test__MAX  cell: TinyTNLM2 - perplexity_test  \
# 0                             158.688461                         115.941415
#
#    cell: TinyTNLM2 - perplexity_test__MIN  \
# 0                              102.393631
#
#    cell: TinyTNLM2 - perplexity_test__MAX
# 0                               164.35553

# %%
x = [5, 10, 20, 25, 30, 35, 40, 45, 50]
y_Large = [158.68,118.43,99.27,97.47,98.15,99.71,101.73,102.42,105]

y_Tiny = [164,126,107,104.17,103.5,103.1,102.40,102.71,102.78]

# %%
plt.plot(x, y_Large,label = "TTLM-Large",linewidth = 3, )
plt.plot(x, y_Tiny,label = "TTLM-Tiny",linewidth = 3,)

plt.xlabel("Rank",fontsize=12)
plt.ylabel("Test Perplexity",fontsize=14)
plt.rc('legend', fontsize=20)
plt.legend()
plt.savefig("image/rank_ppl_test.png",dpi = 600)

# %%
y_rnn_various_embedding = [181,137,115,111,107.8,107,102.84,101.46,100.35]
y_rnn_100 = [166.2,137.2,118.6,113.4,112.5,111.4,109.2,110,109.1]
y_rnn_200 = [164.7,136.4,116.3,113.0,109.8,106.5,105.5,105.5,104.6]
y_rnn_300 = [165.1,136.3,116.4,113.5,109.3,107.1,104.3,103.48,101.44]
plt.figure(dpi= 200)
plt.plot(x, y_rnn_various_embedding, label = "RNNs", linewidth = 3,marker='o',linestyle=':')
plt.plot(x, y_rnn_100, label = "RNNs-100", linewidth = 3, marker='o',linestyle=':')
plt.plot(x, y_rnn_200, label = "RNNs-200", linewidth = 3, marker='o',linestyle=':')
plt.plot(x, y_rnn_300, label = "RNNs-300", linewidth = 3, marker='o',linestyle=':')
plt.plot(x, y_Large,label = "TTLM-Large",linewidth = 3,marker='o')
plt.plot(x, y_Tiny,label = "TTLM-Tiny",linewidth = 3,marker='o')
plt.xlabel("Hidden Size (Rank)",fontsize =xlabel_size)
plt.ylabel("Test PPL",fontsize=ylabel_size)
plt.rc('legend', fontsize=15)
plt.legend()
plt.savefig("image/comparision_with_rnn.png",dpi = 600)

# %% [markdown]
# # Comparision for different rank for TTLM-Large and TTLM-Tiny

# %%
df_rank_comparision = pd.read_csv("draw_data/rank_ptb_val_ppl_TTLM_Large.csv")
df_rank_comparision.head()
# Out:
#    Step  rank: 50 - perplexity_valid  rank: 50 - perplexity_valid__MIN  \
# 0     0                   226.583008                        226.583008
# 1     2                   188.620407                        188.620407
# 2     4                   165.060364                        165.060364
# 3     6                   152.326141                        152.326141
# 4     8                   143.838943                        143.838943
#
#    rank: 50 - perplexity_valid__MAX  rank: 45 - perplexity_valid  \
# 0                        226.583008                   232.826889
# 1                        188.620407                   191.275864
# 2                        165.060364                   170.292435
# 3                        152.326141                   155.470734
# 4                        143.838943                   146.343445
#
#    rank: 45 - perplexity_valid__MIN  rank: 45 - perplexity_valid__MAX  \
# 0                        232.826889                        232.826889
# ...

# %%
plt.figure(dpi= 200)
plt.plot(df_rank_comparision['Step'],df_rank_comparision['rank: 10 - perplexity_valid'],label = "rank=10",linewidth = 3)
plt.plot(df_rank_comparision['Step'],df_rank_comparision['rank: 20 - perplexity_valid'],label = "rank=20",linewidth = 3)
plt.plot(df_rank_comparision['Step'],df_rank_comparision['rank: 30 - perplexity_valid'],label = "rank=30",linewidth = 3)
plt.plot(df_rank_comparision['Step'],df_rank_comparision['rank: 40 - perplexity_valid'],label = "rank=40",linewidth = 3)
plt.plot(df_rank_comparision['Step'],df_rank_comparision['rank: 50 - perplexity_valid'],label = "rank=50",linewidth = 3)
plt.xlabel("training step",fontsize = xlabel_size)
plt.ylabel("Validation PPL",fontsize=ylabel_size)
plt.rc('legend', fontsize=15)
plt.legend()
plt.savefig("image/rank_val_ppl_Large.png",dpi = 600)

# %%
df_tiny = pd.read_csv("draw_data/rank_ptb_val_ppl_TTLN_Tiny.csv")
plt.figure(dpi= 200)
plt.plot(df_tiny['Step'],df_tiny['rank: 10 - perplexity_valid'],label = "rank=10",linewidth = 3)
plt.plot(df_tiny['Step'],df_tiny['rank: 20 - perplexity_valid'],label = "rank=20",linewidth = 3)
plt.plot(df_tiny['Step'],df_tiny['rank: 30 - perplexity_valid'],label = "rank=30",linewidth = 3)
plt.plot(df_tiny['Step'],df_tiny['rank: 40 - perplexity_valid'],label = "rank=40",linewidth = 3)
plt.plot(df_tiny['Step'],df_tiny['rank: 50 - perplexity_valid'],label = "rank=50",linewidth = 3)
plt.xlabel("training step",fontsize = xlabel_size)
plt.ylabel("Validation PPL",fontsize=ylabel_size)
plt.rc('legend', fontsize=15)
plt.legend()
plt.savefig("image/rank_val_ppl_Tiny.png",dpi = 600)

# %%
df_rank_comparision = pd.read_csv("draw_data/TTLM-Large.csv")
df_rank_comparision.head()
# Out:
#    epoch  rank: 50 - _step  rank: 50 - _step__MIN  rank: 50 - _step__MAX  \
# 0      0                 0                      0                      0
# 1      1                 2                      2                      2
# 2      2                 4                      4                      4
# 3      3                 6                      6                      6
# 4      4                 8                      8                      8
#
#    rank: 50 - perplexity_valid  rank: 50 - perplexity_valid__MIN  \
# 0                   226.583008                        226.583008
# 1                   188.620407                        188.620407
# 2                   165.060364                        165.060364
# 3                   152.326141                        152.326141
# 4                   143.838943                        143.838943
#
#    rank: 50 - perplexity_valid__MAX  rank: 30 - _step  rank: 30 - _step__MIN  \
# ...

# %%
plt.figure(dpi= 200)
plt.plot(df_rank_comparision['epoch'],df_rank_comparision['rank: 10 - perplexity_valid'],label = "rank=10",linewidth = 3)
plt.plot(df_rank_comparision['epoch'],df_rank_comparision['rank: 20 - perplexity_valid'],label = "rank=20",linewidth = 3)
plt.plot(df_rank_comparision['epoch'],df_rank_comparision['rank: 30 - perplexity_valid'],label = "rank=30",linewidth = 3)
plt.plot(df_rank_comparision['epoch'],df_rank_comparision['rank: 40 - perplexity_valid'],label = "rank=40",linewidth = 3)
plt.plot(df_rank_comparision['epoch'],df_rank_comparision['rank: 50 - perplexity_valid'],label = "rank=50",linewidth = 3)
plt.xlabel("Epoch",fontsize = xlabel_size)
plt.ylabel("Validation PPL",fontsize=ylabel_size)
plt.rc('legend', fontsize=15)
plt.legend()
# plt.savefig("image/rank_val_ppl_Large.png",dpi = 600)

# %%
df_tiny = pd.read_csv("draw_data/TTLM-Tiny.csv")
plt.figure(dpi= 200)
plt.plot(df_tiny['epoch'],df_tiny['rank: 10 - perplexity_valid'],label = "rank=10",linewidth = 3)
plt.plot(df_tiny['epoch'],df_tiny['rank: 20 - perplexity_valid'],label = "rank=20",linewidth = 3)
plt.plot(df_tiny['epoch'],df_tiny['rank: 30 - perplexity_valid'],label = "rank=30",linewidth = 3)
plt.plot(df_tiny['epoch'],df_tiny['rank: 40 - perplexity_valid'],label = "rank=40",linewidth = 3)
plt.plot(df_tiny['epoch'],df_tiny['rank: 50 - perplexity_valid'],label = "rank=50",linewidth = 3)
plt.xlabel("Epoch",fontsize = xlabel_size)
plt.ylabel("Validation PPL",fontsize=ylabel_size)
plt.rc('legend', fontsize=15)
plt.legend()
# plt.savefig("image/rank_val_ppl_Tiny.png",dpi = 600)

# %%
fontsize = 30
plt.figure(figsize=(12,10), dpi= 200)
plt.rc('xtick', labelsize=fontsize)    # fontsize of the tick labels
plt.rc('ytick', labelsize=fontsize) 
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(30, 10))

ax1.plot(df_rank_comparision['epoch'],df_rank_comparision['rank: 10 - perplexity_valid'],label = "rank=10",linewidth = 3)
ax1.plot(df_rank_comparision['epoch'],df_rank_comparision['rank: 20 - perplexity_valid'],label = "rank=20",linewidth = 3)
ax1.plot(df_rank_comparision['epoch'],df_rank_comparision['rank: 30 - perplexity_valid'],label = "rank=30",linewidth = 3)
ax1.plot(df_rank_comparision['epoch'],df_rank_comparision['rank: 40 - perplexity_valid'],label = "rank=40",linewidth = 3)
ax1.plot(df_rank_comparision['epoch'],df_rank_comparision['rank: 50 - perplexity_valid'],label = "rank=50",linewidth = 3)
# ax1.set_title("(a) Validation PPL on TTLM-Large")
ax1.set_ylabel("Validation PPL",fontsize = fontsize)
ax1.set_xlabel("Epoch",fontsize = fontsize)
ax1.set_title('(a) Validation PPL on TTLM-Large',y=-0.2,pad=-30, fontsize = fontsize)

ax1.set_ylim([100,300])
ax2.plot(df_tiny['epoch'],df_tiny['rank: 10 - perplexity_valid'],label = "rank=10",linewidth = 3)
ax2.plot(df_tiny['epoch'],df_tiny['rank: 20 - perplexity_valid'],label = "rank=20",linewidth = 3)
ax2.plot(df_tiny['epoch'],df_tiny['rank: 30 - perplexity_valid'],label = "rank=30",linewidth = 3)
ax2.plot(df_tiny['epoch'],df_tiny['rank: 40 - perplexity_valid'],label = "rank=40",linewidth = 3)
ax2.plot(df_tiny['epoch'],df_tiny['rank: 50 - perplexity_valid'],label = "rank=50",linewidth = 3)
ax2.set_title("(b) Validation PPL on TTLM-Tiny",y=-0.2,pad=-30, fontsize = fontsize)
ax2.set_xlabel("Epoch",fontsize = fontsize)



ax2.set_ylim([100,300])
handles, labels = ax2.get_legend_handles_labels()
fig.legend(handles, labels, loc='upper center', fancybox=True, shadow=True, ncol=5,fontsize = 25)
